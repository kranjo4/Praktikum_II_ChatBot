# %%
# !pip install scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 4.8 MB/s eta 0:00:00
# ...

# %%
import scrapy
import re

# %%
class GorenjeProstostojeciHladilnikiSpider(scrapy.Spider):
  name="hladilniki_spider"
  allowed_domains=['si.gorenje.com']
  start_urls=['https://si.gorenje.com/izdelki/hlajenje/prostostojeci-hladilniki/c/gocool01?Page=10']
  custom_settings= {
      'FEEDS': {
          'ProstostojeciHladilniki.json':{
              'format': 'json',
              'encoding': 'utf8',
              'overwrite': True
          }
      }
  }

  def parse(self, response):

        naslednje_strani = response.css('a.table-product-info__title::attr(href)').extract()
        print(naslednje_strani)
        for i in naslednje_strani:
            url = 'https://si.gorenje.com/'+i
            yield scrapy.Request(url, callback=self.parse_subpage)
            # yield scrapy.Request('https://www.friko.si/friko-vodnicek/slovenija-j-primorska/osp', callback=self.parse_subpage)

  def parse_subpage(self, response):


        std = {}
        product_title = response.css('div.product-gallery__title')
        std['Ime_hladilnika'] = product_title.css('::text').extract_first()
        std['Serijska_stevilka'] = product_title.css('::attr(data-product-item-name)').extract_first()
        std['Kategorija'] = product_title.css('::attr(data-product-main-category)').extract_first()
        image_url = response.css('div.slider-picture img::attr(src)').extract_first()
        std['Slika'] = image_url

        old_price_text = response.css('div.price__old::text').extract_first().strip()
        old_price_value = old_price_text.replace('€', '').replace(',', '.').strip()
        std['Redna_Cena'] = old_price_value

        new_price_value = response.css('div.price__new::attr(val)').extract_first().strip()
        std['Trenutna_Cena'] = new_price_value

        tech_specs = response.css('div.tech-specs__item')
        for spec in tech_specs:
            label = spec.css('div.tech-specs__item-label::text').extract_first().strip()
            label = label.replace(' ', '_')
            content = spec.css('div.tech-specs__item-content::text').extract_first().strip()
            std[label] = content


        yield std

# %%
from scrapy.crawler import CrawlerProcess
process = CrawlerProcess()
process.crawl(GorenjeProstostojeciHladilnikiSpider)
process.start()
# Out:
# INFO:scrapy.utils.log:Scrapy 2.11.2 started (bot: scrapybot)
# 2024-05-22 12:02:07 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# INFO:scrapy.utils.log:Versions: lxml 4.9.4.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.9.1, w3lib 2.1.2, Twisted 24.3.0, Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0], pyOpenSSL 24.1.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.7, Platform Linux-6.1.85+-x86_64-with-glibc2.35
# 2024-05-22 12:02:07 [scrapy.utils.log] INFO: Versions: lxml 4.9.4.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.9.1, w3lib 2.1.2, Twisted 24.3.0, Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0], pyOpenSSL 24.1.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.7, Platform Linux-6.1.85+-x86_64-with-glibc2.35
# INFO:scrapy.addons:Enabled addons:
# []
# 2024-05-22 12:02:07 [scrapy.addons] INFO: Enabled addons:
# []
# ...

# %%
import pandas as pd

df=pd.read_json("ProstostojeciHladilniki.json")
df.shape
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# 2024-05-22 12:02:20 [numexpr.utils] INFO: NumExpr defaulting to 2 threads.
# (57, 100)

# %%
print(df.to_string())
# Out:
#                                                       Ime_hladilnika Serijska stevilka                      Kategorija                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Slika Redna_Cena  Trenutna_Cena                 Družina_izdelka Način_postavitve Razred_energijske_učinkovitosti Razred_hrupa Lokacija_zamrzovalnega_prostora                   Barva_izdelka                         Barva_vrat           Material_vrat                     Odpiranje_vrat               Izvedba_podstavka Število_zvezdic Klimatski_razredi Skupna_prostornina Prostornina_hladiln
# ...
